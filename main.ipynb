# %%
# %run prepare.ipynb
# %run train.ipynb
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/paulanwesha01/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/paulanwesha01/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = load_data('emails.csv')
# Out:
# Sample of 5 rows from the DataFrame:
#                                                    text  spam
# 1411  Subject: investment  to all whom it may concer...     0
# 4278  Subject: entouch newsletter  business highligh...     0
# 884   Subject: at your serrvice  hello , welcome to ...     1
# 5510  Subject: re : your visit with vince kaminski -...     0
# 241   Subject: [ ilug - social ] prirodu requiremus ...     1
#
# Shape of the DataFrame: (5728, 2)

# %%
df = data_cleaning(df)
# Out:
# Missing values:
#  text    0
# spam    0
# dtype: int64
#
# Duplicate rows: 33
# Shape of the DataFrame after cleaning: (5695, 2)

# %%
EDA(df)
# Out:
# Overall Descriptive Statistics:
#        num_characters    num_words  num_sentences
# count     5695.000000  5695.000000    5695.000000
# mean      1558.067076   328.214047      19.462511
# std       2047.078711   419.654234      35.981993
# min         13.000000     3.000000       1.000000
# 25%        508.500000   102.000000       7.000000
# 50%        979.000000   211.000000      12.000000
# 75%       1893.000000   403.000000      22.000000
# max      43952.000000  8479.000000    1565.000000
#
# Descriptive Statistics for Non-Spam Emails:
#        num_characters    num_words  num_sentences
# count     4327.000000  4327.000000    4327.000000
# mean      1634.200139   347.283799      19.838225
# std       1965.016383   407.227757      38.124564
# min         13.000000     3.000000       1.000000
# 25%        577.500000   120.000000       7.000000
# 50%       1122.000000   240.000000      13.000000
# 75%       2037.500000   440.500000      22.000000
# ...

# %%
df = data_preprocessing(df)
df
# Out:
#                                                    text  spam  \
# 0     Subject: naturally irresistible your corporate...     1
# 1     Subject: the stock trading gunslinger  fanny i...     1
# 2     Subject: unbelievable new homes made easy  im ...     1
# 3     Subject: 4 color printing special  request add...     1
# 4     Subject: do not have money , get software cds ...     1
# ...                                                 ...   ...
# 5723  Subject: re : research and development charges...     0
# 5724  Subject: re : receipts from visit  jim ,  than...     0
# 5725  Subject: re : enron case study update  wow ! a...     0
# 5726  Subject: re : interest  david ,  please , call...     0
# 5727  Subject: news : aurora 5 . 2 update  aurora ve...     0
#
#                                                  tokens  \
# 0     [Subject, :, naturally, irresistible, your, co...
# 1     [Subject, :, the, stock, trading, gunslinger, ...
# ...

# %%
performance_df, validation_results = build_and_validate_models(df)

print(performance_df)
print(validation_results)
# Out:
# For  SVC
# Accuracy -  0.990342405618964
# Precision -  0.9929328621908127
# For  KN
# Accuracy -  0.9771729587357331
# Precision -  0.9782608695652174
# For  NB
# Accuracy -  0.9850746268656716
# Precision -  0.989247311827957
# For  DT
# Accuracy -  0.9236172080772608
# Precision -  0.8048048048048048
# For  LR
# Accuracy -  0.971027216856892
# Precision -  0.9706959706959707
# For  RF
# Accuracy -  0.9824407374890255
# Precision -  0.9927007299270073
# /Users/paulanwesha01/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# For  AdaBoost
# Accuracy -  0.9692712906057945
# Precision -  0.967032967032967
# For  BgC
# Accuracy -  0.9657594381035997
# Precision -  0.9403508771929825
# For  ETC
# Accuracy -  0.9833187006145742
# Precision -  0.9927272727272727
# For  GBDT
# ...

# %%
models = {
            'SVC': SVC(),
            'MultinomialNB': MultinomialNB(),
            'ExtraTreesClassifier': ExtraTreesClassifier()
        }

benchmark_models, evaluation_scores, best_model, evaluation_scores_ensemble = best_model(df, models)

print("Evaluation Scores for benchmark models:")
for name, scores in evaluation_scores.items():
    print(f"{name}: Accuracy - {scores['Accuracy']}, Precision - {scores['Precision']}")

print(f"\nBest Model: {best_model}")

print("\nStacking Classifier Evaluation Scores:")
print("Accuracy:", evaluation_scores_ensemble['Accuracy'])
print("Precision:", evaluation_scores_ensemble['Precision'])
# Out:
# Evaluation Scores for benchmark models:
# SVC: Accuracy - 0.9841966637401229, Precision - 0.9884169884169884
# MultinomialNB: Accuracy - 0.897278314310799, Precision - 0.9873417721518988
# ExtraTreesClassifier: Accuracy - 0.9683933274802459, Precision - 0.9957805907172996
#
# Best Model: SVC
#
# Stacking Classifier Evaluation Scores:
# Accuracy: 0.9947322212467077
# Precision: 0.988929889298893
